# %%
import piplite
await piplite.install('seaborn')

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
dataset = pd.read_csv('weight-height.csv')
dataset.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
dataset.nunique()
# Out:
# Gender        2
# Height    10000
# Weight    10000
# dtype: int64

# %%
dataset['Height'] = dataset['Height']*2.5
dataset['Weight'] = dataset['Weight']/2.5
dataset.head()
# Out:
#   Gender      Height     Weight
# 0   Male  184.617543  96.757425
# 1   Male  171.954760  64.924189
# 2   Male  185.275263  85.096342
# 3   Male  179.327446  88.016988
# 4   Male  174.704490  82.539920

# %%
dfm = dataset[dataset["Gender"] == "Male"]
dfm

dfw = dataset[dataset["Gender"] == "Female"]
dfw
# Out:
#       Gender      Height     Weight
# 5000  Female  147.276830  40.835331
# 5001  Female  163.075031  56.522329
# 5002  Female  158.422509  52.416561
# 5003  Female  161.199994  51.268604
# 5004  Female  154.482740  51.912563
# ...      ...         ...        ...
# 9995  Female  165.431630  54.710982
# 9996  Female  167.667887  68.347162
# 9997  Female  159.669981  51.390128
# 9998  Female  172.585608  65.540985
# 9999  Female  154.860615  45.459641
#
# [5000 rows x 3 columns]

# %%
dataset.hist()
plt.show()

# %%
dfm.hist()
plt.show()

# %%
dfm.hist()
plt.show()

# %%
def amountRows(dfm):
  return len(dfm)
amountRows(dfm)
# Out:
# 5000

# %%
def mean(coloumn):
  sumValues = 0
  for i in coloumn:
    sumValues += i
  return sumValues / amountRows(coloumn)
mean(dfm['Weight'])
# Out:
# 74.80824826327729

# %%
def Variance(column):
  mathMean = mean(column)
  for i in column:
    variance = (i - mathMean)**2
  return (1/mathMean)*variance;
Variance (dfm['Weight'])
# Out:
# 0.30198001092237525

# %%
dfm['Weight'].mean()
# Out:
# 74.80824826327728

# %%
dfm['Weight'].std()
# Out:
# 7.91246180670552

# %%
dfm['Weight'].min()
# Out:
# 45.1611757791272

# %%
dfm['Weight'].max()
# Out:
# 107.99587940204239

# %%
X = dataset.iloc[:, [ 1, 2]].values

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
print(wcss)
# Out:
# [2574482.5347045576, 811672.6363454589, 470015.87258621264, 319334.2073823993, 244459.12691152332, 201749.50312369879, 174429.92958137512, 154930.14895903433, 141082.02592836798, 129772.93986336744]

# %%
kmeans = KMeans(n_clusters = 4, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(X)

# %%
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters of customers')
plt.xlabel('')
plt.ylabel('')
plt.legend()
plt.show()

# %%
print(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1])
# Out:
# [171.95476011 171.96270313 170.87128878 ... 170.10266282 167.66788662
#  172.58560783] [64.92418901 73.57115544 67.1884442  ... 68.20568505 68.34716236
#  65.54098454]

# %%
print(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1])
# Out:
# [171.95476011 171.96270313 170.87128878 ... 170.10266282 167.66788662
#  172.58560783] [64.92418901 73.57115544 67.1884442  ... 68.20568505 68.34716236
#  65.54098454]

# %%
print(X[y_kmeans == 4, 0], X[y_kmeans == 4, 1])
# Out:
# [] []

# %%
kmeans.predict([[166, 47]])
# Out:
# array([1])

# %%
true_dataset = pd.read_csv('weight-height.csv')

# %%
true_dataset.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
clusters = true_dataset.iloc[:,2].values
print(clusters)
# Out:
# [241.89356318 162.31047252 212.74085556 ... 128.47531878 163.85246135
#  113.64910268]

# %%
clusters = dataset.iloc[:,2].values
print(clusters)
# Out:
# [96.75742527 64.92418901 85.09634222 ... 51.39012751 65.54098454
#  45.45964107]

# %%
from sklearn import metrics
metrics.rand_score(clusters, y_kmeans)
# Out:
# /lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:64: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# 0.741816601660166

# %%
from sklearn.cluster import AgglomerativeClustering
hc = AgglomerativeClustering(n_clusters = 4, affinity = 'euclidean', linkage = 'ward')
y_hc = hc.fit_predict(X)

# %%
plt.scatter(X[y_hc == 0, 0], X[y_hc == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_hc == 1, 0], X[y_hc == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
plt.title('Clusters of customers')
plt.xlabel('')
plt.ylabel(')')
plt.legend()
plt.show()

# %%
from sklearn import metrics
metrics.rand_score(clusters, y_hc)
# Out:
# /lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:64: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# 0.6795075707570757

# %%
import scipy.cluster.hierarchy as sch
dendrogram = sch.dendrogram(sch.linkage(X, method = 'ward'))
plt.title('Dendrogram')
plt.xlabel('')
plt.ylabel('')
plt.show()

# %%
dataset.loc[dataset["Gender"] == "Male", "Gender"] = 1

# %%
dataset.loc[dataset["Gender"] == "Female", "Gender"] = 0

# %%
dataset.head()
# Out:
#   Gender      Height     Weight
# 0      1  184.617543  96.757425
# 1      1  171.954760  64.924189
# 2      1  185.275263  85.096342
# 3      1  179.327446  88.016988
# 4      1  174.704490  82.539920

# %%
kmeans.predict([[156, 47]])
# Out:
# array([2])

# %%
from sklearn import metrics
metrics.rand_score(clusters, y_hc)
# Out:
# /lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:64: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# 0.6795075707570757

# %%
dfm.describe()
# Out:
#             Height       Weight
# count  5000.000000  5000.000000
# mean    172.565865    74.808248
# std       7.158406     7.912462
# min     146.017262    45.161176
# 25%     167.936698    69.555107
# 50%     172.569271    74.813418
# 75%     177.471859    80.143121
# max     197.496856   107.995879

# %%
dfw.describe()
# Out:
#             Height       Weight
# count  5000.000000  5000.000000
# mean    159.271934    54.344037
# std       6.740710     7.608987
# min     135.657833    25.880051
# 25%     154.736104    49.173638
# 50%     159.327310    54.447033
# 75%     163.908913    59.524371
# max     183.473965    80.894885

# %%
dataset.describe()
# Out:
#              Height        Weight
# count  10000.000000  10000.000000
# mean     165.918899     64.576143
# std        9.618820     12.843376
# min      135.657833     25.880051
# 25%      158.764051     54.327221
# 50%      165.795175     64.485171
# 75%      172.935654     74.867810
# max      197.496856    107.995879

# %%
kmeans.predict([[172,73]])
# Out:
# array([0])

# %%
kmeans.score([[172,73]])
# Out:
# -7.9067062564382855

# %%
from sklearn import metrics
metrics.rand_score(clusters, ykmeans)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 2
#       1 from sklearn import metrics
# ----> 2 metrics.rand_score(clusters, kmeans)
#
# File /lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:296, in rand_score(labels_true, labels_pred)
#     239 def rand_score(labels_true, labels_pred):
#     240     """Rand index.
#     241
#     242     The Rand Index computes a similarity measure between two clusterings
#    (...)
#     294     .. https://en.wikipedia.org/wiki/Rand_index
#     295     """
# --> 296     contingency = pair_confusion_matrix(labels_true, labels_pred)
#     297     numerator = contingency.diagonal().sum()
#     298     denominator = contingency.sum()
#
# File /lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:221, in pair_confusion_matrix(labels_true, labels_pred)
#     161 def pair_confusion_matrix(labels_true, labels_pred):
#     162     """Pair confusion matrix arising from two clusterings.
#     163
#     164     The pair confusion matrix :math:`C` computes a 2 by 2 similarity matrix
#    (...)
#     219       https://link.springer.com/article/10.1007%2FBF01908075
#     220     """
# --> 221     labels_true, labels_pred = check_clusterings(labels_true, labels_pred)
#     222     n_samples = np.int64(labels_true.shape[0])
#     224     # Computation using the contingency data
#
# File /lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:56, in check_clusterings(labels_true, labels_pred)
#      48 labels_pred = check_array(
#      49     labels_pred,
#      50     ensure_2d=False,
#      51     ensure_min_samples=0,
#      52     dtype=None,
#      53 )
#      55 type_label = type_of_target(labels_true)
# ---> 56 type_pred = type_of_target(labels_pred)
#      58 if "continuous" in (type_pred, type_label):
#      59     msg = (
#      60         "Clustering metrics expects discrete values but received"
#      61         f" {type_label} values for label, and {type_pred} values "
#      62         "for target"
#      63     )
#
# File /lib/python3.10/site-packages/sklearn/utils/multiclass.py:318, in type_of_target(y, input_name)
#     315     pass
#     317 # Invalid inputs
# --> 318 if y.ndim > 2 or (y.dtype == object and len(y) and not isinstance(y.flat[0], str)):
#     319     return "unknown"  # [[[1, 2]]] or [obj_1] and not ["label_1"]
#     321 if y.ndim == 2 and y.shape[1] == 0:
#
# TypeError: len() of unsized object
